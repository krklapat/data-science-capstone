# %% [markdown]
# # Pulling Grid Status Data

# %%
import os
import pandas as pd
from gridstatusio import GridStatusClient

# %%
# Initialize client (Set API key in environment or pass directly)
# To get API Key go to gridstatus website > Settings > API > generate API Key
#os.environ["GRIDSTATUS_API_KEY"] = "API_KEY"  # Replace with your actual API key
client = GridStatusClient()

# %%
# Define parameters for data pull
hub_location = "MINN.HUB"
start_date = "2025-01-01"
end_date = "2026-01-01"

# %% [markdown]
# ## 5 minute real time LMP

# %%
# Pull Data from GridStatus API
df_rtm = client.get_dataset(
    dataset="miso_lmp_real_time_5_min",
    start=start_date,
    end=end_date,
    filter_column="location",
    filter_value=hub_location,
)
print("Real-Time Sample Rows:")
print(df_rtm.head(10))
# Out:
# 2026-09-16 15:40:15 - INFO - Fetching Page 1...
# 2026-09-16 15:40:15 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_lmp_real_time_5_min/query
# 2026-09-16 15:40:15 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': 'location', 'filter_value': 'MINN.HUB', 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 15:40:49 - INFO - Done in 33.24 seconds.
# 2026-09-16 15:40:49 - INFO - Fetching Page 2...
# 2026-09-16 15:40:49 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_lmp_real_time_5_min/query
# 2026-09-16 15:40:49 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 2, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyIsImxvY2F0aW9uIl0sInZhbHVlcyI6WyIyMDI1LTA2LTI1IDA0OjUwOjAwKzAwOjAwIiwiTUlOTi5IVUIiXSwidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOjUwMDAwfQ==', 'filter_column': 'location', 'filter_value': 'MINN.HUB', 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 15:40:55 - INFO - Done in 6.01 seconds. Total time: 39.26s. Avg per page: 19.63s
# 2026-09-16 15:40:55 - INFO - Fetching Page 3...
# 2026-09-16 15:40:55 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_lmp_real_time_5_min/query
# 2026-09-16 15:40:55 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 3, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyIsImxvY2F0aW9uIl0sInZhbHVlcyI6WyIyMDI1LTEyLTE3IDE4OjU1OjAwKzAwOjAwIiwiTUlOTi5IVUIiXSwidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOjEwMDAwMH0=', 'filter_column': 'location', 'filter_value': 'MINN.HUB', 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 15:40:55 - INFO - Done in 0.65 seconds. Total time: 39.91s. Avg per page: 13.3s
# 2026-09-16 15:40:55 - INFO - Total number of rows: 104064
# Real-Time Sample Rows:
#          interval_start_utc          interval_end_utc           market  \
# 0 2025-01-01 00:00:00+00:00 2025-01-01 00:05:00+00:00  REAL_TIME_5_MIN
# 1 2025-01-01 00:05:00+00:00 2025-01-01 00:10:00+00:00  REAL_TIME_5_MIN
# 2 2025-01-01 00:10:00+00:00 2025-01-01 00:15:00+00:00  REAL_TIME_5_MIN
# 3 2025-01-01 00:15:00+00:00 2025-01-01 00:20:00+00:00  REAL_TIME_5_MIN
# 4 2025-01-01 00:20:00+00:00 2025-01-01 00:25:00+00:00  REAL_TIME_5_MIN
# 5 2025-01-01 00:25:00+00:00 2025-01-01 00:30:00+00:00  REAL_TIME_5_MIN
# 6 2025-01-01 00:30:00+00:00 2025-01-01 00:35:00+00:00  REAL_TIME_5_MIN
# 7 2025-01-01 00:35:00+00:00 2025-01-01 00:40:00+00:00  REAL_TIME_5_MIN
# 8 2025-01-01 00:40:00+00:00 2025-01-01 00:45:00+00:00  REAL_TIME_5_MIN
# 9 2025-01-01 00:45:00+00:00 2025-01-01 00:50:00+00:00  REAL_TIME_5_MIN
#
#    location location_type    lmp  energy  congestion  loss
# 0  MINN.HUB           Hub  23.74   23.91        1.42 -1.59
# 1  MINN.HUB           Hub  20.34   24.13       -2.09 -1.70
# 2  MINN.HUB           Hub  20.15   23.88       -2.06 -1.67
# 3  MINN.HUB           Hub  23.18   23.30        1.54 -1.66
# 4  MINN.HUB           Hub  21.63   22.48        0.78 -1.63
# 5  MINN.HUB           Hub  17.41   22.16       -3.07 -1.68
# 6  MINN.HUB           Hub  16.23   22.09       -4.17 -1.69
# 7  MINN.HUB           Hub  18.03   22.33       -2.66 -1.64
# 8  MINN.HUB           Hub  23.25   22.58        2.23 -1.56
# 9  MINN.HUB           Hub  23.83   25.63       -0.14 -1.66

# %%
df_rtm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104064 entries, 0 to 104063
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   interval_start_utc  104064 non-null  datetime64[ns, UTC]
#  1   interval_end_utc    104064 non-null  datetime64[ns, UTC]
#  2   market              104064 non-null  object
#  3   location            104064 non-null  object
#  4   location_type       104064 non-null  object
#  5   lmp                 104064 non-null  float64
#  6   energy              104064 non-null  float64
#  7   congestion          104064 non-null  float64
#  8   loss                104064 non-null  float64
# dtypes: datetime64[ns, UTC](2), float64(4), object(3)
# memory usage: 7.1+ MB

# %%
# Save the data to a parquet file
os.makedirs("raw_data", exist_ok=True)
df_rtm.set_index("interval_start_utc", inplace=True)
df_rtm.to_parquet(f"raw_data/rtm_data_{start_date}_{end_date}.parquet", index=True)

# %% [markdown]
# ## 1 Hour Day Ahead LMP

# %%
df_dam = client.get_dataset(
    dataset="miso_lmp_day_ahead_hourly",
    start=start_date,
    end=end_date,
    filter_column="location",
    filter_value=hub_location,
)
print("Day-Ahead Sample Rows:")
print(df_dam.head(10))
# Out:
# 2026-09-16 15:50:51 - INFO - Fetching Page 1...
# 2026-09-16 15:50:51 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_lmp_day_ahead_hourly/query
# 2026-09-16 15:50:51 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': 'location', 'filter_value': 'MINN.HUB', 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 15:50:53 - INFO - Done in 1.42 seconds.
# 2026-09-16 15:50:53 - INFO - Total number of rows: 8760
# Day-Ahead Sample Rows:
#          interval_start_utc          interval_end_utc            market  \
# 0 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00  DAY_AHEAD_HOURLY
# 1 2025-01-01 01:00:00+00:00 2025-01-01 02:00:00+00:00  DAY_AHEAD_HOURLY
# 2 2025-01-01 02:00:00+00:00 2025-01-01 03:00:00+00:00  DAY_AHEAD_HOURLY
# 3 2025-01-01 03:00:00+00:00 2025-01-01 04:00:00+00:00  DAY_AHEAD_HOURLY
# 4 2025-01-01 04:00:00+00:00 2025-01-01 05:00:00+00:00  DAY_AHEAD_HOURLY
# 5 2025-01-01 05:00:00+00:00 2025-01-01 06:00:00+00:00  DAY_AHEAD_HOURLY
# 6 2025-01-01 06:00:00+00:00 2025-01-01 07:00:00+00:00  DAY_AHEAD_HOURLY
# 7 2025-01-01 07:00:00+00:00 2025-01-01 08:00:00+00:00  DAY_AHEAD_HOURLY
# 8 2025-01-01 08:00:00+00:00 2025-01-01 09:00:00+00:00  DAY_AHEAD_HOURLY
# 9 2025-01-01 09:00:00+00:00 2025-01-01 10:00:00+00:00  DAY_AHEAD_HOURLY
#
#    location location_type    lmp  energy  congestion  loss
# 0  MINN.HUB           Hub  22.23   29.36       -5.91 -1.22
# 1  MINN.HUB           Hub  20.02   28.07       -5.67 -2.38
# 2  MINN.HUB           Hub  19.30   26.61       -6.11 -1.20
# 3  MINN.HUB           Hub  19.31   26.02       -6.38 -0.33
# 4  MINN.HUB           Hub  18.86   24.84       -4.96 -1.02
# 5  MINN.HUB           Hub  22.46   22.77       -0.61  0.30
# 6  MINN.HUB           Hub  20.13   22.31       -2.46  0.28
# 7  MINN.HUB           Hub  19.12   21.35       -2.50  0.27
# 8  MINN.HUB           Hub  19.78   20.93       -0.66 -0.49
# 9  MINN.HUB           Hub  19.62   21.47       -2.13  0.28

# %%
# Save the day-ahead data to a parquet file
os.makedirs("raw_data", exist_ok=True)
df_dam.set_index("interval_start_utc", inplace=True)
df_dam.to_parquet(f"raw_data/dam_data_{start_date}_{end_date}.parquet", index=True)

# %% [markdown]
# ## Load Forecast

# %%
df_load = client.get_dataset(
    dataset="miso_load_forecast",
    start=start_date,
    end=end_date,
)
print("Load Forecast Sample Rows:")
print(df_load.head(10))
# Out:
# 2026-09-16 15:56:15 - INFO - Fetching Page 1...
# 2026-09-16 15:56:15 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_load_forecast/query
# 2026-09-16 15:56:15 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 15:56:19 - INFO - Done in 3.83 seconds.
# 2026-09-16 15:56:19 - INFO - Fetching Page 2...
# 2026-09-16 15:56:19 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_load_forecast/query
# 2026-09-16 15:56:19 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 2, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyIsInB1Ymxpc2hfdGltZV91dGMiXSwidmFsdWVzIjpbIjIwMjUtMDYtMjMgMTQ6MzU6MDArMDA6MDAiLCIyMDI1LTA2LTIzIDA1OjAwOjAwKzAwOjAwIl0sInRvdGFsX3Jvd3NfcmV0dXJuZWRfc29fZmFyIjo1MDAwMH0=', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 15:56:21 - INFO - Done in 2.3 seconds. Total time: 6.13s. Avg per page: 3.06s
# 2026-09-16 15:56:21 - INFO - Fetching Page 3...
# 2026-09-16 15:56:21 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_load_forecast/query
# 2026-09-16 15:56:21 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 3, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyIsInB1Ymxpc2hfdGltZV91dGMiXSwidmFsdWVzIjpbIjIwMjUtMTItMTQgMDU6MTU6MDArMDA6MDAiLCIyMDI1LTEyLTEzIDA1OjAwOjAwKzAwOjAwIl0sInRvdGFsX3Jvd3NfcmV0dXJuZWRfc29fZmFyIjoxMDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 15:56:22 - INFO - Done in 0.5 seconds. Total time: 6.62s. Avg per page: 2.21s
# 2026-09-16 15:56:22 - INFO - Total number of rows: 105120
# Load Forecast Sample Rows:
#          interval_start_utc          interval_end_utc  \
# 0 2025-01-01 00:00:00+00:00 2025-01-01 00:05:00+00:00
# 1 2025-01-01 00:05:00+00:00 2025-01-01 00:10:00+00:00
# 2 2025-01-01 00:10:00+00:00 2025-01-01 00:15:00+00:00
# 3 2025-01-01 00:15:00+00:00 2025-01-01 00:20:00+00:00
# 4 2025-01-01 00:20:00+00:00 2025-01-01 00:25:00+00:00
# 5 2025-01-01 00:25:00+00:00 2025-01-01 00:30:00+00:00
# 6 2025-01-01 00:30:00+00:00 2025-01-01 00:35:00+00:00
# 7 2025-01-01 00:35:00+00:00 2025-01-01 00:40:00+00:00
# 8 2025-01-01 00:40:00+00:00 2025-01-01 00:45:00+00:00
# 9 2025-01-01 00:45:00+00:00 2025-01-01 00:50:00+00:00
#
#            publish_time_utc  load_forecast
# 0 2024-12-31 05:00:00+00:00          76523
# 1 2024-12-31 05:00:00+00:00          76434
# 2 2024-12-31 05:00:00+00:00          76345
# 3 2024-12-31 05:00:00+00:00          76256
# 4 2024-12-31 05:00:00+00:00          76166
# 5 2024-12-31 05:00:00+00:00          76077
# 6 2024-12-31 05:00:00+00:00          75988
# 7 2024-12-31 05:00:00+00:00          75866
# 8 2024-12-31 05:00:00+00:00          75744
# 9 2024-12-31 05:00:00+00:00          75622

# %%
# Save the Load Forecast data to a parquet file
os.makedirs("raw_data", exist_ok=True)
df_load.set_index("interval_start_utc", inplace=True)
df_load.to_parquet(f"raw_data/load_data_{start_date}_{end_date}.parquet", index=True)

# %% [markdown]
# ## Solar Forecast

# %%
df_solar = client.get_dataset(
    dataset="miso_solar_forecast_hourly",
    start=start_date,
    end=end_date,
)
print("Solar Forecast Sample Rows:")
print(df_solar.head(10))
# Out:
# 2026-09-16 16:00:48 - INFO - Fetching Page 1...
# 2026-09-16 16:00:48 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_solar_forecast_hourly/query
# 2026-09-16 16:00:48 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 16:00:50 - INFO - Done in 1.89 seconds.
# 2026-09-16 16:00:50 - INFO - Fetching Page 2...
# 2026-09-16 16:00:50 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_solar_forecast_hourly/query
# 2026-09-16 16:00:50 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 2, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyIsInB1Ymxpc2hfdGltZV91dGMiXSwidmFsdWVzIjpbIjIwMjUtMTAtMjcgMTQ6MDA6MDArMDA6MDAiLCIyMDI1LTEwLTI2IDIzOjM5OjMzKzAwOjAwIl0sInRvdGFsX3Jvd3NfcmV0dXJuZWRfc29fZmFyIjo1MDAwMH0=', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 16:00:50 - INFO - Done in 0.68 seconds. Total time: 2.57s. Avg per page: 1.29s
# 2026-09-16 16:00:50 - INFO - Total number of rows: 60816
# Solar Forecast Sample Rows:
#          interval_start_utc          interval_end_utc  \
# 0 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 1 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 2 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 3 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 4 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 5 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 6 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 7 2025-01-01 01:00:00+00:00 2025-01-01 02:00:00+00:00
# 8 2025-01-01 01:00:00+00:00 2025-01-01 02:00:00+00:00
# 9 2025-01-01 01:00:00+00:00 2025-01-01 02:00:00+00:00
#
#            publish_time_utc  north  central  south  miso
# 0 2024-12-25 23:34:23+00:00    0.0      0.0   52.0  52.0
# 1 2024-12-26 23:34:02+00:00    0.0      0.0    0.0   0.0
# 2 2024-12-27 23:34:19+00:00    0.0      0.0   52.0  52.0
# 3 2024-12-28 23:35:06+00:00    0.0      0.0   52.0  52.0
# 4 2024-12-29 23:35:18+00:00    0.0      0.0   52.0  52.0
# 5 2024-12-30 23:34:45+00:00    0.0      0.0   52.0  52.0
# 6 2024-12-31 23:35:16+00:00    0.0      0.0   52.0  52.0
# 7 2024-12-25 23:34:23+00:00    0.0      0.0    0.0   0.0
# 8 2024-12-26 23:34:02+00:00    0.0      0.0    0.0   0.0
# 9 2024-12-27 23:34:19+00:00    0.0      0.0    0.0   0.0

# %%
# Save the Solar Forecast data to a parquet file
os.makedirs("raw_data", exist_ok=True)
# Don't index by interval_start_utc for solar data, as each interval is published 6 times (one for each forecast horizon)
df_solar.to_parquet(f"raw_data/solar_data_{start_date}_{end_date}.parquet", index=False)

# %% [markdown]
# ## Wind Forecast

# %%
df_wind = client.get_dataset(
    dataset="miso_wind_forecast_hourly",
    start=start_date,
    end=end_date,
)
print("Wind Forecast Sample Rows:")
print(df_wind.head(10))
# Out:
# 2026-09-16 16:04:47 - INFO - Fetching Page 1...
# 2026-09-16 16:04:47 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_wind_forecast_hourly/query
# 2026-09-16 16:04:47 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 16:04:50 - INFO - Done in 2.4 seconds.
# 2026-09-16 16:04:50 - INFO - Fetching Page 2...
# 2026-09-16 16:04:50 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_wind_forecast_hourly/query
# 2026-09-16 16:04:50 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 2, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyIsInB1Ymxpc2hfdGltZV91dGMiXSwidmFsdWVzIjpbIjIwMjUtMTAtMjcgMTQ6MDA6MDArMDA6MDAiLCIyMDI1LTEwLTI2IDIzOjM5OjMzKzAwOjAwIl0sInRvdGFsX3Jvd3NfcmV0dXJuZWRfc29fZmFyIjo1MDAwMH0=', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 16:04:51 - INFO - Done in 1.12 seconds. Total time: 3.52s. Avg per page: 1.76s
# 2026-09-16 16:04:51 - INFO - Total number of rows: 60816
# Wind Forecast Sample Rows:
#          interval_start_utc          interval_end_utc  \
# 0 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 1 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 2 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 3 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 4 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 5 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 6 2025-01-01 00:00:00+00:00 2025-01-01 01:00:00+00:00
# 7 2025-01-01 01:00:00+00:00 2025-01-01 02:00:00+00:00
# 8 2025-01-01 01:00:00+00:00 2025-01-01 02:00:00+00:00
# 9 2025-01-01 01:00:00+00:00 2025-01-01 02:00:00+00:00
#
#            publish_time_utc    north  central  south     miso
# 0 2024-12-25 23:34:23+00:00   9496.0   2427.9  103.7  12027.6
# 1 2024-12-26 23:34:02+00:00  14769.4   5039.4   96.5  19905.3
# 2 2024-12-27 23:34:19+00:00  15878.5   4370.8  114.5  20363.8
# 3 2024-12-28 23:35:06+00:00  15425.5   3560.7   91.8  19078.0
# 4 2024-12-29 23:35:18+00:00  14588.2   5033.3   80.0  19701.5
# 5 2024-12-30 23:34:45+00:00  14272.7   5463.5  110.4  19846.6
# 6 2024-12-31 23:35:16+00:00  14902.0   5447.4  106.2  20455.6
# 7 2024-12-25 23:34:23+00:00   9154.9   2392.1  100.4  11647.4
# 8 2024-12-26 23:34:02+00:00  14886.2   4982.6   92.7  19961.5
# 9 2024-12-27 23:34:19+00:00  16066.5   4372.7  111.8  20551.0

# %%
# Save the Wind Forecast data to a parquet file
os.makedirs("raw_data", exist_ok=True)
# Don't index by interval_start_utc for wind data, as each interval is published 6 times (one for each forecast horizon)
df_wind.to_parquet(f"raw_data/wind_data_{start_date}_{end_date}.parquet", index=False)

# %% [markdown]
# ## Outage Forecast

# %%
df_outage = client.get_dataset(
    dataset="miso_generation_outages_forecast",
    start=start_date,
    end=end_date,
)
print("Outage Forecast Sample Rows:")
print(df_outage.head(10))
# Out:
# 2026-09-16 16:07:20 - INFO - Fetching Page 1...
# 2026-09-16 16:07:20 - INFO - GET https://api.gridstatus.io/v1/datasets/miso_generation_outages_forecast/query
# 2026-09-16 16:07:20 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2026-01-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': None, 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-09-16 16:07:21 - INFO - Done in 0.94 seconds.
# 2026-09-16 16:07:21 - INFO - Total number of rows: 10164
# Outage Forecast Sample Rows:
#          interval_start_utc          interval_end_utc  \
# 0 2025-01-01 05:00:00+00:00 2025-01-02 05:00:00+00:00
# 1 2025-01-01 05:00:00+00:00 2025-01-02 05:00:00+00:00
# 2 2025-01-01 05:00:00+00:00 2025-01-02 05:00:00+00:00
# 3 2025-01-01 05:00:00+00:00 2025-01-02 05:00:00+00:00
# 4 2025-01-01 05:00:00+00:00 2025-01-02 05:00:00+00:00
# 5 2025-01-01 05:00:00+00:00 2025-01-02 05:00:00+00:00
# 6 2025-01-01 05:00:00+00:00 2025-01-02 05:00:00+00:00
# 7 2025-01-01 05:00:00+00:00 2025-01-02 05:00:00+00:00
# 8 2025-01-01 05:00:00+00:00 2025-01-02 05:00:00+00:00
# 9 2025-01-01 05:00:00+00:00 2025-01-02 05:00:00+00:00
#
#            publish_time_utc   region  derated_outages_mw  forced_outages_mw  \
# 0 2024-12-25 05:00:00+00:00  Central                1343               1232
# 1 2024-12-25 05:00:00+00:00     MISO                4626               1871
# 2 2024-12-25 05:00:00+00:00    North                 603                469
# 3 2024-12-25 05:00:00+00:00    South                2680                170
# 4 2024-12-26 05:00:00+00:00  Central                1580               1748
# 5 2024-12-26 05:00:00+00:00     MISO                4883               2487
# 6 2024-12-26 05:00:00+00:00    North                 623                469
# 7 2024-12-26 05:00:00+00:00    South                2680                270
# 8 2024-12-27 05:00:00+00:00  Central                1788               1767
# 9 2024-12-27 05:00:00+00:00     MISO                5164               2506
#
#    planned_outages_mw  unplanned_outages_mw
# 0                6476                2408.0
# 1                8767                3620.0
# 2                 682                 962.0
# 3                1609                 250.0
# 4                6476                2516.0
# 5                8767                3737.0
# 6                 682                 971.0
# 7                1609                 250.0
# 8                6476                2516.0
# 9                8767                4069.0

# %%
# Save the Outage Forecast data to a parquet file
os.makedirs("raw_data", exist_ok=True)
# Don't index by interval_start_utc for outage data, as each interval is published 6 times (one for each forecast horizon) and also once per region
df_outage.to_parquet(f"raw_data/outage_data_{start_date}_{end_date}.parquet", index=False)
